# %%
cd ..
# Out:
# C:\Users\xuc1\OneDrive - Aalto University\Program\codes\py_createc

# %%
import py_createc.Createc_pyFile as cpf
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
img = cpf.DAT_IMG("data/A200306.161609.dat")
plt.imshow(img.img_array_list[0], cmap="gray")

# %%
img = cpf.DAT_IMG("data/Createc2200306.092842.dat")
plt.imshow(img.img_array_list[0], cmap="gray")

# %%
spec = cpf.VERT_SPEC('data/A190824.135614.vert')
plt.plot(spec.spec['Z'], spec.spec['ADC1'])

# %%
img = cpf.DAT_IMG("data/A200619.213320.dat")
plt.imshow(img.imgs[0], cmap="gray")

# %%
img.img_pixels
# Out:
# (229, 512)
